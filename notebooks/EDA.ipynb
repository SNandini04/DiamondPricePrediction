# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\diamondprice\venv\lib\site-packages (6.22.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: pyzmq>=20 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (6.2)
# Requirement already satisfied: packaging in c:\diamondprice\venv\lib\site-packages (from ipykernel) (23.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: comm>=0.1.1 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (8.2.0)
# Requirement already satisfied: nest-asyncio in c:\diamondprice\venv\lib\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: psutil in c:\diamondprice\venv\lib\site-packages (from ipykernel) (5.9.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\diamondprice\venv\lib\site-packages (from ipykernel) (8.12.0)
# Requirement already satisfied: pickleshare in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: colorama in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: backcall in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: typing-extensions in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.5.0)
# Requirement already satisfied: stack-data in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.15.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\diamondprice\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\diamondprice\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\diamondprice\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (6.3.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\diamondprice\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.2.0)
# Requirement already satisfied: pywin32>=300 in c:\diamondprice\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: zipp>=0.5 in c:\diamondprice\venv\lib\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\diamondprice\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\diamondprice\venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\diamondprice\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: pure-eval in c:\diamondprice\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\diamondprice\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\diamondprice\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
## Data Ingestion 
df = pd.read_csv('Data/gemstoneprice.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# ##### No Missing Values Present In The Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %% [markdown]
# ##### Dropping Id Feature Axis=1

# %%
df=df.drop(labels=['id'],axis=1)

# %%
df.describe()
# Out:
#                carat          depth          table              x
# count  193573.000000  193573.000000  193573.000000  193573.000000  \
# mean        0.790688      61.820574      57.227675       5.715312
# std         0.462688       1.081704       1.918844       1.109422
# min         0.200000      52.100000      49.000000       0.000000
# 25%         0.400000      61.300000      56.000000       4.700000
# 50%         0.700000      61.900000      57.000000       5.700000
# 75%         1.030000      62.400000      58.000000       6.510000
# max         3.500000      71.600000      79.000000       9.650000
#
#                    y              z          price
# count  193573.000000  193573.000000  193573.000000
# mean        5.720094       3.534246    3969.155414
# std         1.102333       0.688922    4034.374138
# min         0.000000       0.000000     326.000000
# 25%         4.710000       2.900000     951.000000
# 50%         5.720000       3.530000    2401.000000
# 75%         6.510000       4.030000    5408.000000
# max        10.010000      31.300000   18818.000000

# %%
## Check For Duplicated Records
df.duplicated().sum()
# Out:
# 0

# %%
### Segregate Numerical And Categorical Columns
numerical_cols = df.columns[df.dtypes!="object"]
categorical_cols = df.columns[df.dtypes=="object"]
print(numerical_cols)
print(categorical_cols)
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_cols].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0

for i in numerical_cols:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
plt.figure(figsize=(10,10))
x=0
for i in categorical_cols:
    sns.countplot(data=df,x=i)
    print('\n')
    plt.show()

# %%
sns.heatmap(df[numerical_cols].corr(),annot=True)
# Out:
# <Axes: >

# %%
### As x,y,z is highly correlated with each other.x is 98% correlated to carat , y is 98% correlated to carat and z is 97% is correlated.
## so x,y and z will also be correlated with each other even though independent features such conditions is called as multicollinearity
### In such conditions we need to drop that columns/features

# %%
##df.drop(labels = ["x","y","z"],axis=1)

# %%
sns.pairplot(df.sample(10000))

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
## Frome Data We See That Cut ,Color and Clarity Is An Ordinal Features

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map = {
    "Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5   
}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {
    "I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8
}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map= {
    "D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7
}

# %%
df['cut']=df['cut'].replace(cut_map)
df['clarity']=df['clarity'].map(clarity_map)
df['color']=df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 10 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    193573 non-null  float64
#  1   cut      193573 non-null  int64
#  2   color    193573 non-null  int64
#  3   clarity  193573 non-null  int64
#  4   depth    193573 non-null  float64
#  5   table    193573 non-null  float64
#  6   x        193573 non-null  float64
#  7   y        193573 non-null  float64
#  8   z        193573 non-null  float64
#  9   price    193573 non-null  int64
# dtypes: float64(6), int64(4)
# memory usage: 14.8 MB
